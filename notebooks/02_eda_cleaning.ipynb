# %%
from pyspark.sql import SparkSession
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyspark.sql.functions as F

spark = SparkSession.builder \
    .appName("NYC Taxi Analysis") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .config("spark.ui.port", "4040") \
    .getOrCreate()

train = spark.read.parquet("/Users/anatolijperederij/PycharmProjects/nyc-taxi-ml-pipeline/data/raw/train")
eval = spark.read.parquet("/Users/anatolijperederij/PycharmProjects/nyc-taxi-ml-pipeline/data/raw/eval")
holdout = spark.read.parquet("/Users/anatolijperederij/PycharmProjects/nyc-taxi-ml-pipeline/data/raw/holdout")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/13 22:38:09 WARN Utils: Your hostname, Anatolijs-MacBook-Air-2.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.14 instead (on interface en0)
# 26/02/13 22:38:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/13 22:38:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/13 22:38:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/13 22:38:10 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
train.count()
# Out:
# 58244348

# %%
train_pd = train.sample(fraction= 0.001, seed = 42).toPandas()
train_pd.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
sns.histplot(data = train_pd, x="total_amount")
plt.title("Total amount distribution")
plt.show()

# %%
sns.histplot(data = train_pd, x="trip_distance")
plt.title("Trip distance distribution")
plt.show()

# %%
train.select(F.min("total_amount"), F.max("total_amount") , F.mean("total_amount"), F.median("total_amount")).show()
# Out:
# [Stage 7:========================>                                 (5 + 7) / 12]
# +-----------------+-----------------+------------------+--------------------+
# |min(total_amount)|max(total_amount)| avg(total_amount)|median(total_amount)|
# +-----------------+-----------------+------------------+--------------------+
# |           -958.4|        429562.25|16.037992702344585|                11.8|
# +-----------------+-----------------+------------------+--------------------+

# %%
train.select(F.min("trip_distance"), F.max("trip_distance") , F.mean("trip_distance"), F.median("trip_distance")).show()
# Out:
# [Stage 10:============================>                            (6 + 6) / 12]
# +------------------+------------------+------------------+---------------------+
# |min(trip_distance)|max(trip_distance)|avg(trip_distance)|median(trip_distance)|
# +------------------+------------------+------------------+---------------------+
# |               0.0|      1.90726288E7| 4.912094451980118|                  1.7|
# +------------------+------------------+------------------+---------------------+

# %% [markdown]
# # price must be above `0$` and 100% below `429562$` so lets delete outliers. Distance can't be 1.90726288E7

# %%
def remove_outliers(df):
    df = df.filter(
        (F.col("total_amount") > 0) & (F.col("total_amount") < 500) &
        (F.col("trip_distance") > 0) & (F.col("trip_distance") < 75)
)

    return df

train = remove_outliers(train)
eval = remove_outliers(eval)
holdout = remove_outliers(holdout)

train.count()
# Out:
# 57892523

# %%
train.describe(["trip_distance", "total_amount" , "fare_amount"]).show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/mm/ltg3d_2n05nb1y0p223lhx8c0000gn/T/ipykernel_35040/3461703960.py in ?()
# ----> 1 train.select([
#       2     F.sum(F.col(c).isNull().cast('int')).alias(c)
#       3     for c in train.columns
#       4 ]).show()
#
# ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/sql/utils.py in ?(*args, **kwargs)
#     278             from pyspark.sql.connect import functions
#     279
#     280             return getattr(functions, f.__name__)(*args, **kwargs)
#     281         else:
# --> 282             return f(*args, **kwargs)
#
# ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/errors/utils.py in ?(*args, **kwargs)
#     304                     set_current_origin(None, None)
#     305             else:
#     306                 spark = SparkSession.getActiveSession()
#     307                 if spark is None:
# --> 308                     return func(*args, **kwargs)
#     309                 assert spark._jvm is not None
#     310                 jvm_pyspark_origin = getattr(
#     311                     spark._jvm, "org.apache.spark.sql.catalyst.trees.PySparkCurrentOrigin"
#
# ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/sql/functions/builtin.py in ?(col)
#     326     Column<'x'>
#     327     >>> column('x')
#     328     Column<'x'>
#     329     """
# --> 330     return _invoke_function("col", col)
#
# ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/sql/functions/builtin.py in ?(name, *args)
#     106     and wraps the result with :class:`~pyspark.sql.Column`.
#     107     """
#     108     from pyspark import SparkContext
#     109
# --> 110     assert SparkContext._active_spark_context is not None
#     111     jf = _get_jvm_function(name, SparkContext._active_spark_context)
#     112     return Column(jf(*args))
#
# AssertionError:

# %%
train = train.repartition(4)  # 4 файла вместо сотен
train.write.mode("overwrite").parquet("../data/processed/train")
eval = eval.repartition(4)  # 4 файла вместо сотен
eval.write.mode("overwrite").parquet("../data/processed/eval")
holdout = holdout.repartition(4)  # 4 файла вместо сотен
holdout.write.mode("overwrite").parquet("../data/processed/holdout")
spark.stop()

# %%
tpd = train.sample(fraction = 0.0005, seed = 42).toPandas()
corr_matrix = tpd.corr(numeric_only=True)
sns.heatmap(data = corr_matrix)
plt.show()
