# %%
from pathlib import Path
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("NYC Taxi Analysis") \
    .master("local[*]") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .config("spark.ui.port", "4040") \
    .getOrCreate()


data_path = Path("../data/raw")
all_files = sorted(data_path.glob("yellow_tripdata_2016-*.parquet"))

train_files = [str(f) for f in all_files if f.name <= "yellow_tripdata_2016-05.parquet"]
eval_files  = [str(f) for f in all_files if f.name == "yellow_tripdata_2016-11.parquet"]
holdout_files = [str(f) for f in all_files if f.name == "yellow_tripdata_2016-12.parquet"]

train = spark.read.parquet(*train_files)
eval = spark.read.parquet(*eval_files) if eval_files else None
holdout = spark.read.parquet(*holdout_files) if holdout_files else None


print(f"train rows : {train.count()}")
print(f"eval rows : {eval.count()}")
print(f"holdout rows : {holdout.count()}")
# Out:
# train rows : 58244348
# eval rows : 10102128
# holdout rows : 10446697

# %%
train_pd = train.limit(10).toPandas()
train_pd.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-01-01 00:12:22   2016-01-01 00:29:14                1
# 1         1  2016-01-01 00:41:31   2016-01-01 00:55:10                2
# 2         1  2016-01-01 00:53:37   2016-01-01 00:59:57                1
# 3         1  2016-01-01 00:13:28   2016-01-01 00:18:07                1
# 4         1  2016-01-01 00:33:04   2016-01-01 00:47:14                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            3.2           1                  N            48           262
# 1            1.0           1                  N           162            48
# 2            0.9           1                  N           246            90
# 3            0.8           1                  N           170           162
# 4            1.8           1                  N           161           140
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         14.0    0.5      0.5        3.06           0.0
# 1             2          9.5    0.5      0.5        0.00           0.0
# 2             2          6.0    0.5      0.5        0.00           0.0
# 3             2          5.0    0.5      0.5        0.00           0.0
# 4             2         11.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount congestion_surcharge airport_fee
# 0                    0.3         18.36                 None        None
# 1                    0.3         10.80                 None        None
# 2                    0.3          7.30                 None        None
# 3                    0.3          6.30                 None        None
# 4                    0.3         12.30                 None        None

# %%
eval_pandas = eval.limit(10).toPandas()
eval_pandas.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-11-01 00:02:29   2016-11-01 00:08:06                1
# 1         1  2016-11-01 00:04:14   2016-11-01 00:11:35                1
# 2         1  2016-11-01 00:12:38   2016-11-01 00:15:58                1
# 3         1  2016-11-01 00:17:48   2016-11-01 00:20:28                1
# 4         1  2016-11-01 00:28:55   2016-11-01 00:31:23                1
# 5         1  2016-11-01 00:20:25   2016-11-01 00:27:30                2
# 6         1  2016-11-01 00:46:55   2016-11-01 00:50:24                1
# 7         1  2016-11-01 00:08:04   2016-11-01 00:14:57                1
# 8         1  2016-11-01 00:18:25   2016-11-01 00:21:05                1
# 9         1  2016-11-01 00:03:33   2016-11-01 00:09:56                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.4           1                  N            48           143
# 1            2.1           1                  N           239            41
# 2            1.0           1                  N            41            42
# 3            0.9           1                  N           239           151
# 4            0.6           1                  N           186            90
# 5            1.6           1                  N           107           162
# 6            0.6           1                  N           163           141
# 7            1.5           1                  N            79           233
# 8            0.2           1                  N           233           229
# 9            1.2           1                  N           161           142
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          6.5    0.5      0.5        1.55           0.0
# 1             1          9.0    0.5      0.5        2.05           0.0
# 2             2          5.5    0.5      0.5        0.00           0.0
# 3             2          4.5    0.5      0.5        0.00           0.0
# 4             1          4.0    0.5      0.5        1.05           0.0
# 5             2          7.5    0.5      0.5        0.00           0.0
# 6             1          4.5    0.5      0.5        1.50           0.0
# 7             2          6.5    0.5      0.5        0.00           0.0
# 8             1          3.0    0.5      0.5        0.01           0.0
# 9             1          6.5    0.5      0.5        2.30           0.0
#
#    improvement_surcharge  total_amount congestion_surcharge airport_fee
# 0                    0.3          9.35                 None        None
# 1                    0.3         12.35                 None        None
# 2                    0.3          6.80                 None        None
# 3                    0.3          5.80                 None        None
# 4                    0.3          6.35                 None        None
# 5                    0.3          8.80                 None        None
# 6                    0.3          7.30                 None        None
# 7                    0.3          7.80                 None        None
# 8                    0.3          4.31                 None        None
# 9                    0.3         10.10                 None        None

# %%
holdout_pandas = holdout.limit(10).toPandas()
holdout_pandas.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-12-01 00:26:26   2016-12-01 00:26:54                1
# 1         1  2016-12-01 00:08:13   2016-12-01 00:24:20                1
# 2         1  2016-12-01 00:36:29   2016-12-01 00:40:16                1
# 3         1  2016-12-01 00:55:28   2016-12-01 01:01:04                1
# 4         2  2016-12-01 00:13:08   2016-12-01 00:29:21                1
# 5         2  2016-12-01 00:43:16   2016-12-01 00:53:22                1
# 6         1  2016-12-01 00:27:18   2016-12-01 00:42:36                1
# 7         1  2016-12-01 00:35:50   2016-12-01 00:38:40                1
# 8         1  2016-12-01 00:19:45   2016-12-01 00:28:24                1
# 9         1  2016-12-01 00:36:40   2016-12-01 00:44:36                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00           1                  Y           145           145
# 1           4.20           1                  N           262           226
# 2           1.10           1                  N           238            75
# 3           1.20           1                  N           237           230
# 4           1.48           1                  N           142           161
# 5           2.25           1                  N           142           262
# 6           3.40           1                  N           234           236
# 7           0.70           1                  N           237           237
# 8           2.20           1                  N           162           107
# 9           1.20           1                  N           114            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          2.5    0.5      0.5        0.00           0.0
# 1             2         15.5    0.5      0.5        0.00           0.0
# 2             2          5.5    0.5      0.5        0.00           0.0
# 3             2          6.5    0.5      0.5        0.00           0.0
# 4             1         11.0    0.5      0.5        3.08           0.0
# 5             1          9.0    0.5      0.5        2.58           0.0
# 6             2         13.5    0.5      0.5        0.00           0.0
# 7             1          4.5    0.5      0.5        1.15           0.0
# 8             2          9.0    0.5      0.5        0.00           0.0
# 9             1          7.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount congestion_surcharge airport_fee
# 0                    0.3          3.80                 None        None
# 1                    0.3         16.80                 None        None
# 2                    0.3          6.80                 None        None
# 3                    0.3          7.80                 None        None
# 4                    0.3         15.38                 None        None
# 5                    0.3         12.88                 None        None
# 6                    0.3         14.80                 None        None
# 7                    0.3          6.95                 None        None
# 8                    0.3         10.30                 None        None
# 9                    0.3          8.30                 None        None

# %%
train = train.repartition(4)  # 4 файла вместо сотен
train.write.parquet("../data/raw/train")
eval = eval.repartition(4)  # 4 файла вместо сотен
eval.write.parquet("../data/raw/eval")
holdout = holdout.repartition(4)  # 4 файла вместо сотен
holdout.write.parquet("../data/raw/holdout")
spark.stop()
# Out:
# [Stage 17:==================================================>       (7 + 1) / 8]
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 holdout = holdout.repartition(4)  # 4 файла вместо сотен
# ----> 2 holdout.write.parquet("../data/raw/holdout")
#
# File ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/sql/readwriter.py:2003, in DataFrameWriter.parquet(self, path, mode, partitionBy, compression)
#    2001     self.partitionBy(partitionBy)
#    2002 self._set_opts(compression=compression)
# -> 2003 self._jwrite.parquet(path)
#
# File ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~/PycharmProjects/nyc-taxi-ml-pipeline/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: [PATH_ALREADY_EXISTS] Path file:/Users/anatolijperederij/PycharmProjects/nyc-taxi-ml-pipeline/data/raw/holdout already exists. Set mode as "overwrite" to overwrite the existing path. SQLSTATE: 42K04
